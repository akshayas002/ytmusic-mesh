# %%
import pandas as pd
df = pd.read_csv("lib.csv")
print(df.ndim)
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Video ID       164 non-null    str
#  1   Song Title     163 non-null    str
#  2   Album Title    163 non-null    str
#  3   Artist Name 1  163 non-null    str
#  4   Artist Name 2  61 non-null     str
#  5   Artist Name 3  14 non-null     str
#  6   Artist Name 4  2 non-null      str
# dtypes: str(7)
# memory usage: 9.1 KB

# %%
 df[["Song Title", "Artist Name 1", "Album Title"]].head()
# Out:
#   Song Title Artist Name 1             Album Title
# 0     20 Min  Lil Uzi Vert  Luv Is Rage 2 (Deluxe)
# 1      2TONE          Yeat        DANGEROUS SUMMER
# 2    3 DRAGS       Vichaar                 3 DRAGS
# 3    5 TO 10   Don Toliver        HARDSTONE PSYCHO
# 4      90210  Travis Scott                   Rodeo

# %%
df = df.rename(columns={
    "Video ID": "video_id"
    "Song Title": "song",
    "Album Title": "album",
    "Artist Name 1": "artist_1",
    "Artist Name 2": "artist_2",
    "Artist Name 3": "artist_3",
    "Artist Name 4": "artist_4"
})

df.head()
